# %% [markdown]
# # Diagrams, Beat Sheets and More
#
# There are several types of diagrams and frameworks that storytellers use to plan stories for books, movies, and other narrative-driven media. Here are some of the most popular:
#
# 1. **Story Arc or Freytag’s Pyramid**
#     - **Description**: This diagram is based on the traditional plot structure and is shaped like a pyramid. It includes stages such as exposition, rising action, climax, falling action, and resolution.
#     - **Use**: This structure is commonly used to outline the progression of a story and the build-up to the climax, showing how tension increases and resolves.
#
# 2. **Three-Act Structure**
#     - **Description**: Divided into three parts — Setup, Confrontation, and Resolution.
#     - **Use**: The three-act structure is popular in screenwriting, guiding writers to introduce the characters and setting, then escalate conflict, and finally resolve the story in the third act.
#
# 3. **Mind Maps**
#     - **Description**: Mind maps branch out ideas from a central theme, allowing creators to visually explore different aspects of their story.
#     - **Use**: Writers often use mind maps to brainstorm characters, settings, themes, and subplots.
#
# 4. **Hero’s Journey (or Monomyth)**
#     - **Description**: A circular diagram that includes stages such as the call to adventure, meeting with a mentor, facing challenges, and returning transformed.
#     - **Use**: This structure is especially common in epic tales and fantasy. It provides a guide for stories where a protagonist undergoes a transformative journey.
#
# 5. **Beat Sheets**
#     - **Description**: Lists of major "beats" or turning points within a story, usually in a linear form.
#     - **Use**: Beat sheets are widely used in screenwriting to break down every significant event, helping writers ensure consistent pacing and story flow.
#
# 6. **Character Arcs**
#     - **Description**: Diagrams or graphs that track a character’s development throughout the story, showing emotional highs and lows, changes in personality, and growth.
#     - **Use**: Character arcs are essential for character-driven stories, helping authors visualize how each character evolves.
#
# 7. **Timeline Diagrams**
#     - **Description**: A horizontal line with events plotted in chronological order.
#     - **Use**: Particularly useful for complex stories or those with multiple timelines, it helps authors keep track of events and ensure consistency.
#
# 8. **Scene Diagrams**
#     - **Description**: Scenes are mapped out as boxes connected by lines, showing the order and relationships of events.
#     - **Use**: Writers use scene diagrams to plan individual scenes and how they contribute to the story’s flow and pacing.

# %%
# We use graphviz to create diagrams
# %pip install graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: graphviz in /home/matt/miniconda3/envs/plotomatic/lib/python3.12/site-packages (0.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load the Story

# %%
# Load latest story from disk
import settings
from model import Story
from IPython.display import display, Markdown

# Get the story from the latest step completed
for i in range(4, 1, -1):
    try:
        story_dir = f"{settings.STORY_DIR}/step_{i}"
        story = Story.load_from_directory(story_dir)
        break
    except Exception as e:
        pass

if not story:
    raise Exception("No story found")

print(story.title)
# Out:
# Beyond the Pixel Veil

# %% [markdown]
# # Three-Act Structure
#
# Not necessarily 3 acts, but here we go.
#
# The **Three-Act Structure** is a classic storytelling framework that divides a narrative into three main sections: **Act 1 (Setup)**, **Act 2 (Confrontation)**, and **Act 3 (Resolution)**. This structure is widely used in screenwriting, novels, and other forms of storytelling. It provides a clear and predictable flow that guides the story's progression, helping writers create narratives with engaging arcs and satisfying resolutions.
#
# ### Breakdown of the Three-Act Structure
#
# #### **Act 1: Setup (Beginning)**
#    - **Purpose**: Introduce the main characters, setting, and the story’s premise. The protagonist’s normal life is established, and the central conflict begins to emerge.
#    - **Key Elements**:
#      - **Exposition**: Introduces the main characters, setting, and tone of the story.
#      - **Inciting Incident**: A crucial event that disrupts the protagonist’s world and kick-starts the plot. It poses a question or problem that the story will resolve.
#      - **First Plot Point**: At the end of Act 1, the protagonist makes a choice or is forced into action, committing them to the story’s journey. This event propels them from the known world into the unknown.
#
# #### **Act 2: Confrontation (Middle)**
#    - **Purpose**: The protagonist faces challenges and obstacles that test their resolve, often causing inner conflict and growth. This act forms the bulk of the story, raising stakes and creating tension.
#    - **Key Elements**:
#      - **Rising Action**: A series of events and challenges intensify the central conflict, deepening the stakes and pushing the protagonist towards growth or change.
#      - **Midpoint**: The story reaches a pivotal moment, often where the protagonist faces a major success or setback, changing their understanding or approach. The stakes are raised even higher.
#      - **Second Plot Point**: Near the end of Act 2, the protagonist faces a crisis or low point, often feeling defeated or questioning their choices. This moment leads directly to the climax.
#
# #### **Act 3: Resolution (End)**
#    - **Purpose**: Resolve the story’s central conflict, bringing the character’s journey to a satisfying conclusion.
#    - **Key Elements**:
#      - **Climax**: The highest point of tension and conflict, where the protagonist faces the primary antagonist or challenge directly. The outcome of this confrontation determines the story’s resolution.
#      - **Falling Action**: After the climax, any remaining issues are resolved, and loose ends are tied up.
#      - **Denouement**: The story wraps up, showing how the protagonist and their world have changed. The protagonist may return to their normal life with new insights or a transformed perspective.
#
# ### Visualizing the Three-Act Structure
#
# A Three-Act Structure can be visualized like this:
#
# ```plaintext
#         Act 1           Act 2           Act 3
#       (Setup)      (Confrontation)   (Resolution)
#
# Exposition    Rising Action     Climax      Denouement
#     \             /                 \             /
#      \_________/                     \_________/
# ```
#
# ### Example of the Three-Act Structure in Practice
#
# Here’s an example of how the Three-Act Structure might look in a typical hero’s journey:
#
# - **Act 1**: Luke Skywalker lives a quiet life on Tatooine until he discovers a message from Princess Leia, setting him on a path to join the Rebellion.
# - **Act 2**: Luke trains with Obi-Wan Kenobi, faces challenges, and suffers losses. At the midpoint, he commits fully to the cause. By the end of Act 2, he’s ready to confront the Empire.
# - **Act 3**: Luke and the Rebels attack the Death Star in a climactic battle. After a high-stakes confrontation, he successfully destroys it, and the galaxy celebrates the victory.
#
# The Three-Act Structure is a time-tested framework that helps create compelling, well-paced narratives with strong arcs, clear turning points, and meaningful resolutions.

# %%
def render_three_act_structure(story):
    """
    Render the acts of a Story object in a 3-act structure format for a writer.
    """
    output = f"# {story.title}\n\n**Genre**: {story.genre}\n\n**Plot Overview**:\n{story.plot_overview}\n\n"
    
    for act in story.acts:
        output += f"## {act.title}\n\n"
        output += f"**Description**: {act.description}\n\n"
        
        for scene in act.scenes:
            output += f"- **Scene: {scene.title}**\n"
            output += f"  * **Description**: {scene.description}\n"
            output += f"  * **Characters Involved**: {', '.join(scene.characters_involved)}\n"
            output += f"  * **Setting**: {scene.setting}\n"
            output += f"  * **Mood**: {scene.mood}\n"
            output += f"  * **Key Actions**:\n"
            for action in scene.key_actions:
                output += f"      - {action}\n"
            output += "\n"
    
    return output

# %%
# Render out the act structure of the story
display(Markdown(render_three_act_structure(story)))
# Out:
# # Beyond the Pixel Veil
#
# **Genre**: Science Fantasy/Young Adult Thriller
#
# **Plot Overview**:
# In the immersive world of Eon, where virtual reality gaming competitions have captivated the globe, 17-year-old Meera 'Midnight' Singh is an unassuming underdog gamer. Her life takes a dramatic turn when she discovers that her VR exploits are inextricably linked to an alternate reality known as the Nexus, where the fabric of space and time hangs in the balance.
#
# As Meera delves deeper into this cosmic convergence, she must confront the unsettling truth: her in-game actions have inadvertently claimed lives in the real world. Torn between guilt and determination, Meera embarks on a transformative journey to harness her extraordinary gaming skills for the greater good.
#
# Forming an unlikely alliance with former rivals - Jax 'Specter' Lee, a brilliant hacker; Dr. Zhang 'Zee' Wei, a soft-spoken genius inventor; and Maya 'Rampart' Patel, a fearless esports athlete - Meera navigates treacherous landscapes, avoids deadly creatures, and uncovers hidden agendas within the Nexus.
#
# As they progress, the team encounters the enigmatic Architect, creator of the Nexus, who reveals shocking truths about the simulated reality and the true purpose of the gaming competitions. Meera and her team must now confront the dark forces manipulating the Nexus, threatening to destroy both the virtual and real worlds.
#
# With each heart-pumping challenge, Meera's team discovers that their diverse skills are not only essential to survival but also to unraveling the mysteries of the Nexus. Through self-discovery, trust, and sacrifice, Meera evolves from an uncertain teenager to a courageous hero, ready to face the ultimate test: saving two worlds from destruction.
#
# **Key Plot Twists:**
#
# 1. **The Nexus Revelation**: Meera discovers her VR actions have real-world consequences.
# 2. **The Architect's True Intentions**: The team learns the shocking purpose behind the gaming competitions.
# 3. **The Shadow Organization**: A hidden force is revealed, manipulating the Nexus for catastrophic gains.
#
# **Themes:**
#
# 1. **Redemption and Self-Discovery**
# 2. **Power of Diversity and Teamwork**
# 3. **Balancing Consequences of Emerging Technologies
#
# ## Act 1: The Nexus Revelation
#
# **Description**: Meera discovers her life is intertwined with an alternate reality, the Nexus.
#
# - **Scene: The Awakening**
#   * **Description**: Meera's VR gaming session reveals an unexpected connection to the Nexus.
#   * **Characters Involved**: meera
#   * **Setting**: Meera's home gaming setup, transitioning to the vibrant world of the Nexus
#   * **Mood**: Intrigue and wonder, with a hint of unease
#   * **Key Actions**:
#       - Meera experiences her first Nexus-induced glitch.
#       - She begins to question the nature of her reality.
#
# - **Scene: Uncovering Midnight's Past**
#   * **Description**: Meera delves into her gaming history, seeking connections to the Nexus.
#   * **Characters Involved**: meera
#   * **Setting**: Meera's cluttered bedroom, with a focus on her gaming station and old gaming memorabilia
#   * **Mood**: Nostalgic and inquisitive
#   * **Key Actions**:
#       - Meera discovers her earliest Nexus-related glitches.
#       - She realizes her unique connection to the Nexus.
#
# ## Act 2: The Unlikely Alliance
#
# **Description**: Meera forms an unlikely team with former rivals to navigate the Nexus's challenges.
#
# - **Scene: Meeting Specter**
#   * **Description**: Meera encounters Jax 'Specter' Lee, a brilliant hacker, in the Nexus.
#   * **Characters Involved**: meera, jax
#   * **Setting**: A futuristic, neon-drenched cityscape within the Nexus
#   * **Mood**: Cautious and exploratory
#   * **Key Actions**:
#       - Meera and Jax engage in a high-stakes hacking challenge.
#       - They form an uneasy alliance.
#
# - **Scene: Dr. Wei's Wisdom**
#   * **Description**: Meera meets Dr. Zhang 'Zee' Wei, who offers guidance on the Nexus.
#   * **Characters Involved**: meera, zee
#   * **Setting**: A serene, futuristic laboratory within the Nexus
#   * **Mood**: Soothing and enlightening
#   * **Key Actions**:
#       - Dr. Wei explains the Nexus's fundamental principles.
#       - Meera gains a deeper understanding of her connection.
#
# ## Act 3: Shadows and Revelations
#
# **Description**: Meera's team confronts the dark forces manipulating the Nexus.
#
# - **Scene: The Architect's Truth**
#   * **Description**: Meera's team meets the enigmatic Architect, revealing shocking truths about the Nexus.
#   * **Characters Involved**: meera, jax, zee, architect
#   * **Setting**: An ethereal, otherworldly realm within the Nexus
#   * **Mood**: Surreal and revelatory
#   * **Key Actions**:
#       - The Architect reveals the true purpose of the gaming competitions.
#       - Meera's team grasps the scope of their challenge.
#
# - **Scene: Facing Umbra**
#   * **Description**: Meera's team confronts Umbra Blackwood, leader of the Shadow Organization.
#   * **Characters Involved**: meera, jax, zee, umbra
#   * **Setting**: A dark, foreboding fortress within the Nexus
#   * **Mood**: Tense and confrontational
#   * **Key Actions**:
#       - Meera's team engages in a high-stakes battle against Umbra's forces.
#       - The true extent of the Shadow Organization's plans is revealed.

# %% [markdown]
# # Beat Sheet
#
# A **beat sheet** is a structured outline that breaks down the major plot points, or "beats," in a story. Each beat represents a specific moment or turning point that drives the plot forward or develops character arcs. Beat sheets are especially popular in screenwriting and are often used to map out the pacing, tension, and emotional impact of a story before writing the full script or manuscript.
#
# A beat sheet serves as a roadmap, helping writers ensure their story progresses logically and maintains momentum. It can be adapted to fit various storytelling structures, including the Three-Act Structure, the Hero’s Journey, and more.
#
# ### Common Beats in a Beat Sheet
#
# While different formats exist, these are the beats typically included in a standard beat sheet for a Three-Act Structure:
#
# #### **Act 1: Setup**
# 1. **Opening Image**: The first impression of the story, showing the protagonist’s world or state before change. Sets the tone and provides a visual hook.
# 2. **Theme Stated**: A hint or statement about the central theme, often presented subtly within dialogue or the setting.
# 3. **Setup**: Introduction to the main characters, setting, and the protagonist's ordinary world, establishing what’s at stake.
# 4. **Catalyst (Inciting Incident)**: The event that disrupts the protagonist’s life and introduces the central conflict.
# 5. **Debate**: The protagonist reacts to the catalyst, hesitating or considering options before fully committing to their journey.
#
# #### **Act 2A: Confrontation (First Half of Act 2)**
# 6. **Break into Act 2**: The protagonist makes a choice or takes action, leaving their ordinary world behind to confront the main conflict.
# 7. **B Story**: Introduction of a subplot or secondary story (often a love interest or friendship) that adds depth to the main plot.
# 8. **Fun and Games**: A lighter section where the protagonist explores the new world or situation, often providing a glimpse of what success could look like.
# 9. **Midpoint**: The story’s turning point. The protagonist faces a major event that raises the stakes, often changing the direction of the story or revealing new information.
#
# #### **Act 2B: Confrontation (Second Half of Act 2)**
# 10. **Bad Guys Close In**: Obstacles intensify as the protagonist faces increasing opposition, and the tension builds. The protagonist may struggle or make mistakes.
# 11. **All Is Lost**: The protagonist hits rock bottom, facing their darkest moment or greatest setback.
# 12. **Dark Night of the Soul**: The protagonist reflects on their journey and struggles with despair, fear, or self-doubt, leading to an inner realization or change.
#
# #### **Act 3: Resolution**
# 13. **Break into Act 3**: The protagonist, renewed with resolve or insight, takes decisive action to confront the central conflict.
# 14. **Finale**: The climax and resolution of the story. The protagonist faces their biggest challenge, often leading to victory, transformation, or a significant outcome.
# 15. **Final Image**: The last moment or image of the story, showing how the protagonist or world has changed since the beginning. Provides closure and reinforces the theme.
#
# ### Example Beat Sheet (for a Hero’s Journey)
#
# | Beat                      | Description                                                                                      |
# |---------------------------|--------------------------------------------------------------------------------------------------|
# | Opening Image             | Introduces the hero in their ordinary world                                                     |
# | Theme Stated              | A hint of the story's theme (e.g., "You can’t run from your destiny.")                           |
# | Catalyst                  | The hero receives a call to adventure (e.g., a message or inciting event)                       |
# | Debate                    | The hero hesitates, unsure whether to accept the challenge                                       |
# | Break into Act 2          | The hero commits to the journey, stepping into the unknown                                      |
# | Fun and Games             | The hero learns about the new world and begins to grow                                          |
# | Midpoint                  | A major event that raises stakes and shifts the hero's goal                                     |
# | Bad Guys Close In         | Increasing obstacles and enemies put pressure on the hero                                       |
# | All Is Lost               | The hero faces their greatest failure or setback                                                |
# | Dark Night of the Soul    | The hero reflects, finding renewed strength or insight                                          |
# | Break into Act 3          | The hero takes decisive action to confront the main conflict                                    |
# | Finale                    | The hero faces the ultimate test, leading to transformation and resolution                      |
# | Final Image               | Shows the hero's return or newfound strength, providing closure                                 |
#
# ### Purpose of a Beat Sheet
#
# A beat sheet helps writers:
# - **Organize Story Structure**: It ensures key moments are included and that the story flows logically from one beat to the next.
# - **Maintain Pacing and Tension**: By outlining the sequence and timing of events, it keeps the story engaging and avoids pacing issues.
# - **Develop Character Arcs**: It maps the protagonist’s journey and emotional growth, ensuring that each event contributes to their transformation.
# - **Guide the Writing Process**: A beat sheet serves as a blueprint for the draft, helping writers stay focused and avoid plot holes.
#
# Beat sheets are flexible and can be as detailed or minimal as needed. They provide a concise overview of the story’s structure, making it easier to maintain focus, balance, and momentum throughout the writing process.

# %%
def create_beat_sheet(story: Story) -> str:
    """
    Createds a beat sheet for the given story in a structured Markdown format.
    
    Parameters:
        story (Story): The story object containing acts, scenes, and story beats.
    """
    beat_sheet_md = f"# Beat Sheet for '{story.title}'\n\n"
    beat_sheet_md += f"**Genre**: {story.genre}\n\n"
    beat_sheet_md += f"**Plot Overview**: {story.plot_overview}\n\n"
    
    # Display story beats
    beat_sheet_md += "## Story Beats\n"
    if story.story_beats:
        for beat in story.story_beats:
            beat_sheet_md += f"### {beat.name}\n"
            beat_sheet_md += f"{beat.description}\n"
            if beat.scene:
                beat_sheet_md += f"**Scene Link**: {beat.scene}\n"
            beat_sheet_md += "\n"
    else:
        beat_sheet_md += "_No story beats defined._\n\n"
    
    # Display acts and scenes
    beat_sheet_md += "## Acts and Scenes\n"
    if story.acts:
        for act in story.acts:
            beat_sheet_md += f"### {act.title}\n"
            beat_sheet_md += f"{act.description}\n\n"
            for scene in act.scenes:
                beat_sheet_md += f"#### Scene: {scene.title}\n"
                beat_sheet_md += f"- **Description**: {scene.description}\n"
                beat_sheet_md += f"- **Location**: {scene.location}, **Time of Day**: {scene.time_of_day}\n"
                beat_sheet_md += f"- **Mood**: {scene.mood}\n"
                beat_sheet_md += f"- **Characters Involved**: {', '.join(scene.characters_involved)}\n"
                beat_sheet_md += f"- **Key Actions**: {', '.join(scene.key_actions)}\n"
                beat_sheet_md += "\n"
    else:
        beat_sheet_md += "_No acts and scenes defined._\n"
    
    # Display emotional arc, if available
    beat_sheet_md += "## Emotional Arc\n"
    if story.emotional_arc:
        for stage in story.emotional_arc:
            beat_sheet_md += f"### {stage.stage}\n"
            beat_sheet_md += f"{stage.description}\n\n"
    else:
        beat_sheet_md += "_No emotional arc defined._\n"

    return beat_sheet_md

# %%
from IPython.display import display, Markdown

beat_sheet = create_beat_sheet(story)
display(Markdown(beat_sheet))
# Out:
# # Beat Sheet for 'Beyond the Pixel Veil'
#
# **Genre**: Science Fantasy/Young Adult Thriller
#
# **Plot Overview**: In the immersive world of Eon, where virtual reality gaming competitions have captivated the globe, 17-year-old Meera 'Midnight' Singh is an unassuming underdog gamer. Her life takes a dramatic turn when she discovers that her VR exploits are inextricably linked to an alternate reality known as the Nexus, where the fabric of space and time hangs in the balance.
#
# As Meera delves deeper into this cosmic convergence, she must confront the unsettling truth: her in-game actions have inadvertently claimed lives in the real world. Torn between guilt and determination, Meera embarks on a transformative journey to harness her extraordinary gaming skills for the greater good.
#
# Forming an unlikely alliance with former rivals - Jax 'Specter' Lee, a brilliant hacker; Dr. Zhang 'Zee' Wei, a soft-spoken genius inventor; and Maya 'Rampart' Patel, a fearless esports athlete - Meera navigates treacherous landscapes, avoids deadly creatures, and uncovers hidden agendas within the Nexus.
#
# As they progress, the team encounters the enigmatic Architect, creator of the Nexus, who reveals shocking truths about the simulated reality and the true purpose of the gaming competitions. Meera and her team must now confront the dark forces manipulating the Nexus, threatening to destroy both the virtual and real worlds.
#
# With each heart-pumping challenge, Meera's team discovers that their diverse skills are not only essential to survival but also to unraveling the mysteries of the Nexus. Through self-discovery, trust, and sacrifice, Meera evolves from an uncertain teenager to a courageous hero, ready to face the ultimate test: saving two worlds from destruction.
#
# **Key Plot Twists:**
#
# 1. **The Nexus Revelation**: Meera discovers her VR actions have real-world consequences.
# 2. **The Architect's True Intentions**: The team learns the shocking purpose behind the gaming competitions.
# 3. **The Shadow Organization**: A hidden force is revealed, manipulating the Nexus for catastrophic gains.
#
# **Themes:**
#
# 1. **Redemption and Self-Discovery**
# 2. **Power of Diversity and Teamwork**
# 3. **Balancing Consequences of Emerging Technologies
#
# ## Story Beats
# ### Inciting Incident
# Meera discovers her VR actions have real-world consequences (Nexus Revelation)
# **Scene Link**: nexus_awakening
#
# ### Plot Point 1
# Meera forms an unlikely alliance with former rivals (Unlikely Alliance)
# **Scene Link**: specter_encounter
#
# ### Midpoint
# Meera gains a deeper understanding of her connection to the Nexus (Dr. Wei's Wisdom)
# **Scene Link**: zee_guidance
#
# ### Plot Point 2
# The Architect reveals the true purpose of the gaming competitions (Architect's Truth)
# **Scene Link**: architect_encounter
#
# ### Climax
# Meera's team confronts Umbra Blackwood, leader of the Shadow Organization (Umbra Confrontation)
# **Scene Link**: umbra_confrontation
#
# ## Acts and Scenes
# ### Act 1: The Nexus Revelation
# Meera discovers her life is intertwined with an alternate reality, the Nexus.
#
# #### Scene: The Awakening
# - **Description**: Meera's VR gaming session reveals an unexpected connection to the Nexus.
# - **Location**: Dual Reality: Earth & The Nexus, **Time of Day**: Late evening
# - **Mood**: Intrigue and wonder, with a hint of unease
# - **Characters Involved**: meera
# - **Key Actions**: Meera experiences her first Nexus-induced glitch., She begins to question the nature of her reality.
#
# #### Scene: Uncovering Midnight's Past
# - **Description**: Meera delves into her gaming history, seeking connections to the Nexus.
# - **Location**: Earth (Meera's home), **Time of Day**: Afternoon
# - **Mood**: Nostalgic and inquisitive
# - **Characters Involved**: meera
# - **Key Actions**: Meera discovers her earliest Nexus-related glitches., She realizes her unique connection to the Nexus.
#
# ### Act 2: The Unlikely Alliance
# Meera forms an unlikely team with former rivals to navigate the Nexus's challenges.
#
# #### Scene: Meeting Specter
# - **Description**: Meera encounters Jax 'Specter' Lee, a brilliant hacker, in the Nexus.
# - **Location**: The Nexus, **Time of Day**: Night
# - **Mood**: Cautious and exploratory
# - **Characters Involved**: meera, jax
# - **Key Actions**: Meera and Jax engage in a high-stakes hacking challenge., They form an uneasy alliance.
#
# #### Scene: Dr. Wei's Wisdom
# - **Description**: Meera meets Dr. Zhang 'Zee' Wei, who offers guidance on the Nexus.
# - **Location**: The Nexus, **Time of Day**: Afternoon
# - **Mood**: Soothing and enlightening
# - **Characters Involved**: meera, zee
# - **Key Actions**: Dr. Wei explains the Nexus's fundamental principles., Meera gains a deeper understanding of her connection.
#
# ### Act 3: Shadows and Revelations
# Meera's team confronts the dark forces manipulating the Nexus.
#
# #### Scene: The Architect's Truth
# - **Description**: Meera's team meets the enigmatic Architect, revealing shocking truths about the Nexus.
# - **Location**: The Nexus (Architect's Realm), **Time of Day**: Eternal dusk
# - **Mood**: Surreal and revelatory
# - **Characters Involved**: meera, jax, zee, architect
# - **Key Actions**: The Architect reveals the true purpose of the gaming competitions., Meera's team grasps the scope of their challenge.
#
# #### Scene: Facing Umbra
# - **Description**: Meera's team confronts Umbra Blackwood, leader of the Shadow Organization.
# - **Location**: The Nexus (Shadow Organization's Hideout), **Time of Day**: Night
# - **Mood**: Tense and confrontational
# - **Characters Involved**: meera, jax, zee, umbra
# - **Key Actions**: Meera's team engages in a high-stakes battle against Umbra's forces., The true extent of the Shadow Organization's plans is revealed.
#
# ## Emotional Arc
# _No emotional arc defined._

# %%
# Convert and save to pdf
import os

beat_sheet_path_md = f"{settings.STORY_DIR}/draft/beat_sheet.md"
beat_sheet_path_pdf = f"{settings.STORY_DIR}/draft/beat_sheet.pdf"

# Ensure the directory exists
os.makedirs(f"{settings.STORY_DIR}/draft", exist_ok=True)

with open(beat_sheet_path_md, "w") as file:
    file.write(beat_sheet)
    print(f"Saved markdown beat sheet to: {beat_sheet_path_md}")

# Can Render to a PDF using pandoc
# !sudo apt -y install pandoc texlive
# !pandoc {beat_sheet_path_md} -o {beat_sheet_path_pdf}
# Out:
# Saved markdown beat sheet to: stories/my_story/draft/beat_sheet.md
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# pandoc is already the newest version (2.9.2.1-3ubuntu2).
# texlive is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 203 not upgraded.

# %% [markdown]
# # Character Arc of Protagonists

# %%
from graphviz import Digraph
import os

def create_character_arc(character, story_dir):
    # Ensure the directory exists
    os.makedirs(story_dir, exist_ok=True)
    
    # Initialize a directed graph
    dot = Digraph("Character Arc", format="png")
    
    arc = character.character_arc

    if not arc:
        return None
    
    # Add nodes for initial and final states
    dot.node("initial", f"Initial State\n({arc.initial_state})")
    dot.node("final", f"Final State\n({arc.final_state})")
    
    # Add nodes and edges for key moments
    previous_stage = "initial"
    for i, moment in enumerate(arc.key_moments):
        stage_id = f"stage_{i}"
        dot.node(stage_id, moment)
        dot.edge(previous_stage, stage_id)
        previous_stage = stage_id
    dot.edge(previous_stage, "final")
    
    # Define the file path to save the graph
    file_path = os.path.join(story_dir, "character_arc_graph")
    dot.render(file_path)  # Render the graph to a file
    
    return file_path + ".png"  # Return the full path to the rendered image

# %%
# Generate graph for character arc
from IPython.display import Image, display, Markdown

draft_dir = f"{settings.STORY_DIR}/draft"

for character in story.characters:
    image_path = create_character_arc(character, draft_dir)
    if not image_path:
        print(f"No character arc defined for {character.name}.")
    else:
        display(Markdown(f"## {character.name}"))
        display(Image(filename=image_path))
# Out:
# ## Meera 'Midnight' Singh
# ## Jax 'Specter' Lee
# No character arc defined for Dr. Zhang 'Zee' Wei.
# No character arc defined for Maya 'Rampart' Patel.
# No character arc defined for The Architect.
# No character arc defined for Nova Snow.
# No character arc defined for Umbra Blackwood.
# No character arc defined for Echo Flux.

# %% [markdown]
# # Timeline Diagram for a Story
#
# A **Timeline Diagram** for a story is a visualization that maps key events, scenes, and character arcs across the chronological timeline of the story. This type of diagram is especially useful for tracking events, understanding temporal relationships between scenes, and managing complex narratives involving multiple plotlines or time jumps.
#
# Here’s a guide to building a **Timeline Diagram** for a story, along with a Python function that uses Graphviz to create the diagram.
#
# ### Purpose of a Timeline Diagram
#
# - **Chronological Overview**: Shows the order of key events, allowing writers and readers to see how the plot unfolds over time.
# - **Tracking Character Arcs**: Helps in tracking character development and involvement across the timeline.
# - **Visualizing Parallel Plotlines**: Useful for stories with multiple intersecting or parallel storylines.
# - **Managing Time Jumps**: Clarifies stories with flashbacks, flashforwards, or non-linear timelines.
# - **Planning and Consistency**: Ensures events and character appearances are consistent and logically ordered.
#
# ### Structure of the Timeline Diagram
#
# In this timeline:
# - Each **Act** can represent a section along the timeline, with scenes shown sequentially within each act.
# - **Events** within scenes are represented as nodes on the timeline, linked in sequence.
# - **Characters** involved in each scene can be indicated to show character presence across the timeline.

# %%
from graphviz import Digraph
import os
from IPython.display import display, Image, Markdown

def create_timeline_diagram(story: Story, story_dir: str) -> str:
    """
    Creates a Timeline Diagram for the story, showing the sequence of acts and scenes over time.

    Parameters:
    - story: Story object containing acts and scenes.
    - story_dir: Directory to save the diagram image.

    Returns:
    - Path to the generated diagram image.
    """
    # Ensure the directory exists
    os.makedirs(story_dir, exist_ok=True)
    
    # Initialize a directed graph
    dot = Digraph("Timeline Diagram", format="png")
    dot.attr(label=story.title, fontsize="20", labelloc="top", rankdir="LR")  # Left-to-right for timeline

    # Add nodes and edges for each act and scene
    for act in story.acts:
        with dot.subgraph(name=f"cluster_{act.act_id}") as sub:
            sub.attr(label=act.title or f"Act {act.act_id}", fontsize="16", style="filled", color="lightgrey")

            # Add scenes as timeline nodes
            for scene in act.scenes:
                scene_label = f"{scene.title}\nTime: {scene.time_of_day}\nLocation: {scene.location}\nCharacters: {', '.join(scene.characters_involved)}"
                sub.node(scene.scene_id, scene_label, shape="ellipse", style="filled", color="lightblue", fontsize="10")

            # Link scenes in order for each act
            for i in range(len(act.scenes) - 1):
                sub.edge(act.scenes[i].scene_id, act.scenes[i + 1].scene_id)

    # Link the last scene of each act to the first scene of the next act to show progression
    for i in range(len(story.acts) - 1):
        last_scene_current_act = story.acts[i].scenes[-1].scene_id
        first_scene_next_act = story.acts[i + 1].scenes[0].scene_id
        dot.edge(last_scene_current_act, first_scene_next_act, style="dashed")

    # Define the file path to save the graph
    file_path = os.path.join(story_dir, f"{story.title}_timeline_diagram")
    dot.render(file_path)  # Render the graph to a file
    
    return file_path + ".png"  # Return the full path to the rendered image

# %%
# Generate a Graphviz diagram based on the structure
import settings

draft_dir = f"{settings.STORY_DIR}/draft"

scene_diagram_path = create_timeline_diagram(story, draft_dir)

# Display the generated image
display(Markdown(f"## Timeline Diagram for '{story.title}'"))
display(Image(filename=scene_diagram_path))
# Out:
# ## Timeline Diagram for 'Beyond the Pixel Veil'

# %% [markdown]
# # Scene Diagram for a Screenplay
#
# A **screenplay scene diagram** is a visual tool used by writers, directors, and production teams to map out the structure, flow, and connections between scenes in a screenplay. Here are some of the main purposes and benefits of using a screenplay scene diagram:
#
# ### 1. **Visualizing Story Structure**
#    - It provides a **bird’s-eye view** of the screenplay, allowing writers and directors to see the flow of scenes within each act.
#    - By visualizing scenes, it becomes easier to identify structural elements like the **beginning, middle, and end** of the story, as well as to pinpoint pivotal scenes like the **inciting incident, climax, and resolution**.
#
# ### 2. **Tracking Character Arcs and Involvement**
#    - A scene diagram can show which **characters are involved** in each scene, making it easier to track character arcs and ensure that each character is meaningfully contributing to the plot.
#    - It helps identify **gaps or inconsistencies** in character presence and development throughout the screenplay.
#
# ### 3. **Ensuring Narrative Continuity**
#    - By visualizing scenes in order, a diagram can highlight **narrative gaps, repetitive elements**, or **sudden shifts** that might disrupt the story’s flow.
#    - This allows writers to see if the **story progression** is logical and smooth, or if there are **missing scenes** or **transitions** that need attention.
#
# ### 4. **Assisting with Pacing and Tension**
#    - The diagram can reveal the **pacing** of the screenplay by showing where scenes with high tension or emotional impact are placed.
#    - It helps ensure that **rising and falling actions** are balanced and appropriately spaced to maintain the audience’s engagement.
#
# ### 5. **Aiding Collaboration Across Production Teams**
#    - For directors, producers, and other members of the production team, a screenplay scene diagram serves as a quick **reference for the screenplay’s structure**.
#    - The diagram helps team members discuss scenes, transitions, and structural elements **without needing to comb through the entire script** each time.
#
# ### 6. **Facilitating Revisions and Edits**
#    - The diagram makes it easy to see where scenes could be **added, removed, or shifted** within the structure.
#    - It provides an overview of the screenplay that can help during **script editing and revisions**, especially when working on **restructuring the story**.
#
# ### 7. **Organizing Production Scheduling**
#    - Knowing the order and connection of scenes aids in **organizing the shooting schedule**, as production teams can better understand how scenes relate and determine if certain scenes need to be shot in sequence or if they can be filmed independently.
#
# ### Summary of Use Cases
#
# A screenplay scene diagram is not only a writing tool but also a **production and planning asset**. It helps clarify the screenplay’s structure, track character involvement, manage pacing, facilitate collaboration, and streamline the editing and production processes.

# %%
from graphviz import Digraph
import os
from IPython.display import display, Image, Markdown

def create_screenplay_scene_diagram(story: Story, story_dir: str) -> str:
    """
    Creates a Graphviz diagram of a screenplay's structure by organizing scenes within acts.

    Parameters:
    - story: Story object containing acts and scenes.
    - story_dir: Directory to save the diagram image.

    Returns:
    - Path to the generated diagram image.
    """
    # Ensure the directory exists
    os.makedirs(story_dir, exist_ok=True)

    # Initialize a directed graph
    dot = Digraph("Screenplay Scene Diagram", format="png")
    dot.attr(label=story.title, fontsize="20", labelloc="top", rankdir="TB")  # Top-to-bottom flow for acts

    # Process each act and its scenes
    for act in story.acts:
        with dot.subgraph(name=f"cluster_{act.act_id}") as sub:
            sub.attr(label=act.title or f"Act {act.act_id}", fontsize="16", style="filled", color="lightgrey")

            # Add scenes within the act
            for scene in act.scenes:
                scene_label = f"{scene.title}\nLocation: {scene.location}\nCharacters: {', '.join(scene.characters_involved)}\nDescription: {scene.description}"
                sub.node(scene.scene_id, scene_label, shape="box", style="rounded,filled", color="lightblue", fontsize="10")

            # Link scenes in sequence within the act
            for i in range(len(act.scenes) - 1):
                sub.edge(act.scenes[i].scene_id, act.scenes[i + 1].scene_id)

    # Link acts in sequence, connecting the last scene of one act to the first scene of the next
    for i in range(len(story.acts) - 1):
        last_scene_current_act = story.acts[i].scenes[-1].scene_id
        first_scene_next_act = story.acts[i + 1].scenes[0].scene_id
        dot.edge(last_scene_current_act, first_scene_next_act, style="dashed")

    # Define the file path to save the graph
    file_path = os.path.join(story_dir, f"{story.title}_scene_diagram")
    dot.render(file_path)  # Render the graph to a file
    
    return file_path + ".png"  # Return the full path to the rendered image

# %%
# Generate a Graphviz diagram based on the structure
import settings

draft_dir = f"{settings.STORY_DIR}/draft"

scene_diagram_path = create_screenplay_scene_diagram(story, draft_dir)

# Display the generated image
display(Markdown(f"## Screenplay Scene Diagram for '{story.title}'"))
display(Image(filename=scene_diagram_path))
# Out:
# ## Screenplay Scene Diagram for 'Beyond the Pixel Veil'

# %% [markdown]
# # Freytag’s Pyramid
#
# **Freytag’s Pyramid** is a framework for structuring dramatic stories, developed by 19th-century German playwright Gustav Freytag. It organizes a story into five key parts, visualized as a pyramid-shaped arc that traces the rise, climax, and resolution of the plot. This structure helps in analyzing and creating stories with a clear beginning, middle, and end, making it particularly useful for traditional narratives.
#
# Here are the five stages of Freytag’s Pyramid:
#
# 1. **Exposition**: This is the story's introduction. It establishes the main characters, setting, and background information, giving the audience a sense of the ordinary world the protagonist inhabits before the central conflict begins.
#
# 2. **Rising Action**: This is where the main conflict is introduced, and tension builds as the protagonist faces challenges, obstacles, and smaller conflicts. These events create suspense and develop the plot, leading up to the climax.
#
# 3. **Climax**: The story's turning point and the moment of highest tension. Here, the main conflict reaches its peak, and the protagonist faces a decisive challenge or choice. This moment often determines the outcome of the story.
#
# 4. **Falling Action**: After the climax, the story moves into the falling action. The conflicts start to resolve, and the story’s tension decreases as the protagonist deals with the consequences of their actions.
#
# 5. **Denouement (Resolution)**: This is the story’s conclusion, where loose ends are tied up, and the protagonist’s journey concludes. It provides a sense of closure, showing how the characters and world have changed.
#
# ### Visualization of Freytag’s Pyramid
#
# Visually, Freytag’s Pyramid resembles a triangle or pyramid with the following progression:
#
# ```
#                                   Climax
#                                 /       \
#                 Rising Action               Falling Action
#             /                                               \
# Exposition                                                    Denouement
# ```
#
# ### Example in a Story
#
# In a classic story, Freytag’s Pyramid might look like this:
#
# - **Exposition**: A young farm boy, Luke, lives on a distant planet, dreaming of adventure.
# - **Rising Action**: Luke joins a rebellion and trains with a mentor to confront a tyrannical empire.
# - **Climax**: Luke faces the Empire’s leader, Darth Vader, and learns shocking truths about his family.
# - **Falling Action**: Luke’s allies strike against the Empire, gaining the upper hand.
# - **Denouement**: Peace is temporarily restored, and Luke continues his journey with new purpose and allies.
#
# Freytag's Pyramid is a helpful framework for structuring stories with a linear, dramatic arc and is widely used in traditional storytelling forms like plays, novels, and films.

# %%
from graphviz import Digraph
import os

def create_freytags_pyramid_graphviz(story_title: str, exposition: str, rising_action: str, climax: str, falling_action: str, denouement: str, story_dir: str) -> str:
    # Ensure the directory exists
    os.makedirs(story_dir, exist_ok=True)
    
    # Initialize a directed graph
    dot = Digraph("Freytag's Pyramid", format="png")
    dot.attr(rankdir='BT')  # Bottom-to-top for a pyramid-like effect
    
    # Define subgraph clusters to control the ranking
    with dot.subgraph() as s:
        s.attr(rank='same')
        s.node("exposition", f"Exposition\n({exposition})")
        s.node("denouement", f"Denouement\n({denouement})")
    
    with dot.subgraph() as s:
        s.attr(rank='same')
        s.node("rising_action", f"Rising Action\n({rising_action})")
        s.node("falling_action", f"Falling Action\n({falling_action})")
    
    # Climax at the top
    dot.node("climax", f"Climax\n({climax})")

    # Connect nodes to form a pyramid shape
    dot.edge("exposition", "rising_action")
    dot.edge("rising_action", "climax")
    dot.edge("climax", "falling_action")
    dot.edge("falling_action", "denouement")
    
    # Define the file path to save the graph
    file_path = os.path.join(story_dir, f"{story_title}_freytags_pyramid")
    dot.render(file_path)  # Render the graph to a file
    
    return file_path + ".png"  # Return the full path to the rendered image

# %%
# Few-shot examples to guide the LLM

from model import Story, Character, CharacterArc, Act, Scene, StoryBeat, EmotionalArc, Subplot
few_shot_story = Story(
    prompt="In a world where people's emotions control the weather, a young girl discovers she has the rare ability to bring calm to any storm. However, she must learn to control her own feelings before she can save her town from an impending disaster.",
    title="The Weather Weaver",
    genre="Fantasy Adventure",
    medium="Book",
    visual_style="Vivid Fantasy",
    time_period="Timeless fantasy setting, with elements of modern-day influences",
    location="A small, scenic village nestled between lush forests and a vast stormy sea",
    plot_overview="In 'The Weather Weaver,' Maya, a sensitive young girl, discovers she has the rare power to influence the weather through her emotions. As she grapples with self-doubt and anxiety, her abilities grow increasingly unpredictable, creating intense storms. With the guidance of her wise grandmother, Iris, Maya learns techniques to find inner calm, bringing peace not only to her surroundings but also within herself. However, her journey is complicated by Jonah, a boy with a stormy disposition and his own powers, who challenges Maya's control. As a catastrophic storm threatens their village, Maya must master her emotions to protect her home and loved ones.",
    narrative_perspective="Third-person limited, focused on Maya's perspective with occasional insights into Jonah's thoughts",
    characters=[
        Character(
            nickname="maya",
            name="Maya, the Weather Weaver",
            role="Protagonist and emotional weather manipulator",
            gender="Female",
            race="Human",
            age="13",
            description="A young girl who discovers her rare ability to influence the weather with her emotions.",
            personality="Sensitive, compassionate, but struggles with self-control.",
            physical_appearance="Petite with curly hair that seems to change color based on her mood.",
            catch_phrase="Stay calm, stay strong.",
            animation_description="Maya's movements are quick but hesitant, often clenching her fists when frustrated and releasing them to breathe deeply when calming herself.",
            voice_description="Soft and unsure at first, but growing steady and clear as she gains confidence.",
            internal_conflict="Wrestles with self-doubt and fear of her powers, afraid she may hurt those around her if she loses control.",
            character_arc=CharacterArc(
                initial_state="Overwhelmed and fearful of her powers.",
                final_state="Confident and able to control her emotions.",
                key_moments=[
                    "Discovers her powers during an argument.",
                    "Receives guidance from Grandmother Iris.",
                    "Learns to calm herself, calming the weather."
                ]
            ),
            image_prompt="Full-body, A digital painting style with watercolor elements of a 13-year-old girl with a petite build, standing with curly hair that shifts in color based on her emotions. Her skin is light with a scattering of freckles across her cheeks. She wears a simple, short-sleeved dress in soft earth tones that falls to her knees, along with worn sneakers. Her expression is both intense and contemplative, with her eyes conveying inner conflict and sensitivity. Her fists are often clenched when she's tense, but her hands relax when she calms. She has a gentle presence, yet there's a subtle strength in her posture.",
            image_prompt_short="Full-body, A digital painting style with watercolor elements of a petite 13-year-old with color-shifting curls, earthy dress, and expressive, conflicted eyes.",
        ),
        Character(
            nickname="grandmother",
            name="Grandmother Iris",
            role="Mentor and wise guide",
            gender="Female",
            race="Human",
            age="70s",
            description="Maya's wise grandmother who teaches her how to control her powers.",
            personality="Patient, nurturing, and full of hidden knowledge.",
            physical_appearance="Elderly with silver hair tied in a bun, always wearing a shawl.",
            catch_phrase="The storm within must be tamed first.",
            animation_description="Grandmother Iris moves with slow, deliberate grace, often placing a calming hand on Maya's shoulder during tense moments.",
            voice_description="Warm and steady with a soft, melodic cadence that soothes those around her.",
            internal_conflict="Remains haunted by her own past mistakes with similar powers, worried Maya may face the same struggles.",
            character_arc=CharacterArc(
                initial_state="Reserved, protecting Maya from deeper knowledge of the past.",
                final_state="More open and trusting of Maya's growth.",
                key_moments=[
                    "Guides Maya through her first calming exercise.",
                    "Shares a personal story to encourage Maya.",
                    "Trusts Maya to handle the coming storm on her own."
                ]
            ),
            image_prompt="Full-body, A digital painting style with watercolor elements of an elderly woman in her 70s with gentle, weathered features. Her silver hair is neatly tied in a bun, with a few soft strands framing her face. She wears a warm, earth-toned shawl draped over her shoulders, covering a simple, ankle-length dress in muted colors. Her skin is fair with visible lines of age, and her eyes are wise and comforting, often with a gentle smile. She stands with a calm, graceful posture, one hand gently reaching out, as if offering guidance.",
            image_prompt_short="Full-body, A digital painting style with watercolor elements of an elderly woman with silver hair in a bun, earthy shawl, gentle and wise eyes.",

        ),
        Character(
            nickname="jonah",
            name="Jonah, the Storm Bringer",
            role="Rival and fellow weather manipulator",
            gender="Male",
            race="Human",
            age="14",
            description="A boy who can summon storms but struggles with his own anger.",
            personality="Rebellious, troubled, but deeply wants to belong.",
            physical_appearance="Tall with wild, wind-swept hair and piercing blue eyes.",
            catch_phrase="Let it rage!",
            animation_description="Jonah's movements are sharp and expressive, his posture tense and defensive, often clenching his jaw when feeling misunderstood.",
            voice_description="Raspy and intense, with an edge of frustration and yearning for connection.",
            internal_conflict="Feels trapped by his own temper and isolation, often lashing out as a means of coping with loneliness.",
            character_arc=CharacterArc(
                initial_state="Angry and unable to control his emotions.",
                final_state="Begins to learn emotional restraint, inspired by Maya.",
                key_moments=[
                    "Clashes with Maya due to his uncontrolled powers.",
                    "Observes Maya's growth with curiosity.",
                    "Begins his own journey toward emotional control."
                ]
            ),
            image_prompt="Full-body, A digital painting style with watercolor elements of a tall, lean 14-year-old boy with a tense, rebellious stance. His dark, wild hair appears wind-swept, as though it's constantly caught in a storm. His piercing blue eyes hold a mix of frustration and yearning for connection. He wears a rugged, slightly oversized jacket over a simple, dark shirt and worn jeans, and sturdy boots. His jaw is often clenched, and his posture is defensive, yet there is a hint of vulnerability in his gaze.",
            image_prompt_short="Full-body, A digital painting style with watercolor elements of a tall, lean 14-year-old boy with wild hair, piercing blue eyes, rugged jacket, and tense stance.",
        ),
    ],
    acts=[
        Act(
            act_id="awakening_the_storm",
            title="Act 1 - Awakening the Storm",
            scenes=[
                Scene(
                    scene_id="storm_beginning",
                    title="The Storm's Beginning",
                    description=(
                        "Maya accidentally causes a storm during an argument at school, revealing her emotional influence on "
                        "the weather. Her frustration escalates as she confronts a group of classmates who mock her for her "
                        "quiet demeanor. She snaps, unleashing a powerful emotional surge."
                    ),
                    setting="A bustling schoolyard where students gather after classes, with dense clouds forming in the sky above.",
                    key_actions=[
                        "Maya raises her voice, feeling her anger boil over, and suddenly thunder rumbles overhead.",
                        "The sky darkens, and rain starts pouring as Maya's frustration peaks, terrifying her classmates.",
                        "Realizing she must stop the storm, Maya desperately tries to calm herself but struggles with her emotions."
                    ],
                    characters_involved=["maya"],
                    location="Schoolyard",
                    time_of_day="Afternoon",
                    lighting="Dark, stormy clouds casting shadows over the schoolyard.",
                    mood="Chaotic and intense, a mix of fear and confusion.",
                    background_animation="Dark clouds roll in swiftly, casting shadows over the schoolyard as the wind picks up. Leaves and debris swirl around. Thunder rumbles and lightning flickers, illuminating startled faces in the crowd. Raindrops begin to pour.",
                    background_image_prompt="A bustling schoolyard with students gathered under dark, stormy clouds. The sky is shadowed, with dense clouds rolling in, casting an eerie darkness over the scene. A strong wind picks up, swirling leaves and loose paper around. Thunder rumbles, and occasional lightning flickers, illuminating the startled faces in the crowd. The atmosphere is chaotic and intense, with the natural elements reflecting the brewing emotional storm.",
                    scene_image_prompt="""A digital painting style with watercolor elements of a bustling schoolyard filled with students, where a powerful storm begins to build.

Layer 1 (Background): The sky is thick with dark, heavy clouds rolling in swiftly, casting an eerie shadow across the scene. Occasional flashes of lightning illuminate the darkening landscape in brief, bright bursts.

Layer 2 (Middle ground): The schoolyard is crowded with students looking up in awe and fear as the storm intensifies. A strong wind swirls leaves and loose paper, creating a chaotic, whirlwind effect through the center of the area.

Layer 3 (Foreground): In the center of the yard stands a young girl with curly hair that darkens and shifts in color, mirroring her rising frustration. Her petite frame is tensed, with clenched fists at her sides, her expressive face filled with a mix of anger and hurt. Around her, classmates watch from a distance, their expressions frightened as they sense her distress. Raindrops begin to fall, heavy and cold, adding to the intense, chaotic atmosphere that reflects the brewing emotional storm within her.""",
                    scene_image_prompt_short="A digital painting style of a stormy schoolyard where a young girl with shifting curls stands at the center of swirling winds and dark clouds, her emotions mirrored in the storm around her. With clenched fists and stormy, shifting hair, she faces her classmates' frightened stares as thunder rumbles and lightning crackles. Raindrops begin to fall, intensifying the tense, chaotic atmosphere.",
                ),
                Scene(
                    scene_id="granmother_visit",
                    title="Grandmother's Wisdom",
                    description=(
                        "Seeking solace after her unsettling experience, Maya visits her grandmother, Iris, who teaches her the "
                        "importance of inner peace in controlling her powers. Iris introduces her to grounding techniques to "
                        "help Maya manage her emotions and calm the weather."
                    ),
                    setting="A cozy, inviting living room filled with the scent of herbs and the soft glow of a crackling fireplace, with rain lightly pattering on the window.",
                    key_actions=[
                        "Iris guides Maya through a breathing exercise, encouraging her to release her frustrations.",
                        "Maya closes her eyes, focusing on her breath, and the storm outside begins to calm, transforming into a gentle rain.",
                        "As Maya achieves a sense of inner calm, the clouds part, and a vibrant rainbow appears outside, signifying her newfound control."
                    ],
                    characters_involved=["maya", "grandmother"],
                    location="Living room",
                    time_of_day="Evening",
                    lighting="Soft, warm glow from the fireplace, with raindrops glistening outside.",
                    mood="Calming and hopeful, with a sense of growth and support.",
                    # background_animation="Raindrops patter rhythmically on the window. The fire crackles gently, casting a warm, steady glow. The rain eases into a soft drizzle, and sunlight filters through the window, creating a rainbow.",
                    # background_image_prompt="A cozy, inviting living room filled with the soft glow of a crackling fireplace. The room is warmly lit, with the scent of herbs and a peaceful ambiance. Raindrops patter gently on the window as light from the fire casts a steady, calming glow across the room. Soft, natural colors and simple decor reflect comfort and wisdom. As the scene progresses, rain outside eases to a drizzle, and a rainbow faintly appears, signaling calm and newfound inner peace.",
                    # scene_image_prompt="In a cozy, warmly lit living room filled with the gentle scent of dried herbs and the crackling of a small fireplace, Maya sits across from her grandmother, Iris, seeking comfort and guidance. Maya, a petite 13-year-old girl with soft, curly hair that subtly shifts in color depending on her emotions, looks at her grandmother with a mixture of uncertainty and hope. She wears a simple, faded dress, her hands resting in her lap, fingers fidgeting as she listens intently. Grandmother Iris, a gentle, elderly woman with silver hair tied back in a neat bun, has a face lined with wisdom and warmth. She wears a soft, worn shawl over her shoulders and holds a calming presence, her steady hands reaching out to gently guide Maya through a breathing exercise. As Maya closes her eyes and breathes deeply, the storm outside the window begins to calm, the rain easing into a soft drizzle. The warm, amber glow from the fireplace bathes the room in a soothing light, creating an atmosphere of safety, growth, and emotional support as a vibrant rainbow begins to form outside, symbolizing Maya's newfound inner peace.",
                    # scene_image_prompt_short="In a cozy living room, Maya, a 13-year-old with color-shifting curls, sits with her grandmother Iris, seeking comfort. Iris, a gentle elder with silver hair, guides Maya through calming breaths. As Maya relaxes, the storm outside eases, and a rainbow forms, symbolizing her newfound inner peace in the warm, soothing glow of the fireplace.",
                    background_animation="A digital painting style with watercolor elements of raindrops pattering rhythmically on the window. The fire crackles gently, casting a warm, steady glow. The rain eases into a soft drizzle, and sunlight filters through the window, creating a rainbow.",
                    background_image_prompt="A digital painting style with watercolor elements of a cozy, inviting living room filled with the soft glow of a crackling fireplace. The room is warmly lit, with the scent of herbs and a peaceful ambiance. Raindrops patter gently on the window as light from the fire casts a steady, calming glow across the room. Soft, natural colors and simple decor reflect comfort and wisdom. As the scene progresses, rain outside eases to a drizzle, and a rainbow faintly appears, signaling calm and newfound inner peace.",
                    scene_image_prompt="""A digital painting style with watercolor elements of a cozy, warmly lit living room filled with the gentle scent of dried herbs and the crackling of a small fireplace.

Layer 1 (Background): Depict a softly lit living room interior with warm, natural tones. A large window shows raindrops pattering rhythmically on the glass, with a gentle drizzle outside beginning to ease. Through the window, hint at the faint outline of a rainbow forming as the sky clears.

Layer 2 (Middle ground): Focus on the inviting room decor and furniture, emphasizing the worn, comforting textures of a well-loved space. Include simple furnishings—a cozy armchair, a small round table with a tea set, and a few scattered books. A glowing fireplace sits nearby, casting a warm amber light that fills the room with a soothing glow.

Layer 3 (Foreground): Center on a young girl with petite features and curly hair that subtly shifts in hue with her emotions. She sits with an elderly woman, her grandmother, who has a gentle face lined with wisdom and wears a soft, worn shawl. The grandmother reaches out to guide the girl through a calming breathing exercise. The girl's expression is a mix of hope and uncertainty as she focuses, her hands resting in her lap. 

Atmosphere: The overall mood should be calm and nurturing, with a soft, ethereal quality to the lighting that highlights the warmth of the scene. As the rain eases, the room exudes a feeling of emotional growth and support, symbolized by the faint rainbow outside.""",

                    scene_image_prompt_short="A digital painting style with watercolor elements of a cozy living room where a young girl with color-shifting curls sits with her elderly grandmother, seeking comfort. The grandmother, a gentle elder with silver hair, guides the girl through calming breaths. As the girl relaxes, the storm outside eases, and a rainbow forms, symbolizing her newfound inner peace in the warm, soothing glow of the fireplace.",
                ),
                Scene(
                    scene_id="encounter_jonah",
                    title="A Mysterious Encounter",
                    description=(
                        "On her way back from her grandmother's house, Maya encounters Jonah, a boy with a mysterious aura and an "
                        "unmistakable power over storms. He challenges her understanding of weather manipulation and the control she "
                        "thinks she's gained."
                    ),
                    setting="A deserted forest path under a brooding, cloudy sky, where thunder rolls in the distance.",
                    key_actions=[
                        "Maya feels a shift in the air, turning to find Jonah standing nearby, his presence intense and foreboding.",
                        "Jonah stirs the air with a slight motion, causing a gust of wind and a flicker of lightning to illuminate the sky.",
                        "The two exchange wary words, with Jonah hinting at the untamed potential in Maya's abilities, leaving her unsettled."
                    ],
                    characters_involved=["maya", "jonah"],
                    location="Forest path",
                    time_of_day="Dusk",
                    lighting="Dark and ominous with flickers of lightning in the distance.",
                    mood="Tense and foreboding, hinting at rivalry and unease.",
                    background_animation="A low wind rustles through the trees, and leaves swirl around. Dark clouds gather overhead, and flashes of lightning periodically illuminate the sky.",
                    background_image_prompt="A digital painting style with watercolor elements of a deserted forest path under a brooding sky, where clouds loom heavily and thunder rumbles in the distance. Shadows fall across the path, with brief flashes of lightning illuminating the dense, ominous surroundings. A light wind stirs leaves and small branches, adding tension to the scene. The atmosphere is dark and tense, suggesting rivalry and unease, as if nature itself reflects the intensity of the encounter.",
                    
                    scene_image_prompt="""A digital painting style with watercolor elements of a deserted, tree-lined forest path under a darkening sky, where two figures stand tensely.

Layer 1 (Background): The sky is thick with dark, swirling clouds that hang low over the path, casting deep shadows across the forest. Occasional flashes of lightning illuminate the scene, briefly lighting up the ominous surroundings and highlighting the dense trees and underbrush.

Layer 2 (Middle ground): The narrow forest path is littered with fallen leaves and small branches that rustle in the light wind. The trees on either side stand tall and foreboding, creating a sense of enclosure and tension. Shadows deepen along the path, contributing to the tense atmosphere.

Layer 3 (Foreground): In the center of the path stands a petite girl with wild, curly hair that subtly shifts in hue with her emotions. She has a wary expression, her posture tense, with slightly hunched shoulders as she faces a taller teenage boy. The boy has a rugged, intense look, with dark, wind-swept hair and piercing blue eyes that convey hidden storms within. He wears a loose, weather-worn jacket and stands with confidence, his gaze intense and foreboding. His subtle movements manipulate the air around him, causing a light gust to stir the leaves at their feet. A smirk plays on his face as he observes the girl's reaction, their standoff simmering with unspoken rivalry. Lightning flashes overhead, casting dramatic shadows that highlight the tension and intensity of their encounter, as if the storm mirrors the rivalry between them.""",
                    
                    scene_image_prompt_short="A digital painting style with watercolor elements of a darkening forest path, where a petite girl with subtly color-shifting curls stands tensely opposite a rugged teenage boy with piercing blue eyes and wind-tousled hair. He smirks, stirring leaves with a light gust, while flashes of lightning illuminate their intense standoff under swirling storm clouds, emphasizing the tension and rivalry between them."

                ),
            ]
        ),
        Act(
            act_id="struggle_for_control",
            title="Act 2 - Struggle for Control",
            scenes=[
                Scene(
                    scene_id="tempest_within",
                    title="The Tempest Within",
                    description=(
                        "Maya continues her training with her grandmother but struggles as her emotions often get the better of her. "
                        "As the pressure to control her powers mounts, she starts doubting herself, creating more turbulent weather."
                    ),
                    setting="Grandmother Iris's backyard garden, a serene place disrupted by Maya's sporadic storms.",
                    key_actions=[
                        "Maya practices her breathing and calming exercises, but frustration causes wind to whip through the garden.",
                        "Iris gently encourages Maya, reminding her to be patient, but Maya's self-doubt causes the storm to worsen.",
                        "As the storm becomes overwhelming, Maya runs away, feeling unable to meet her grandmother's expectations."
                    ],
                    characters_involved=["maya", "grandmother"],
                    location="Iris's backyard garden",
                    time_of_day="Morning",
                    lighting="Soft daylight, dimmed by sudden dark clouds as Maya struggles.",
                    mood="Frustration and anxiety, with a tone of inner conflict and self-doubt.",
                    background_animation="The garden blooms sway as gusts of wind sweep through the space. Storm clouds gather, darkening the sky. Leaves scatter, and a soft drizzle begins.",
                    background_image_prompt="A digital painting style with watercolor elements of a serene backyard garden filled with colorful blooms, suddenly disrupted by stormy weather as dark clouds gather overhead. The sky dims, and a soft drizzle begins as gusts of wind rustle through plants. Leaves and petals are scattered by the wind, reflecting the tension and inner turmoil of the scene. The contrast between the garden's natural beauty and the sudden storm creates a visually striking representation of conflict and frustration.",
                    scene_image_prompt="""A digital painting style with watercolor elements of a tranquil backyard garden, where a sudden storm disrupts the peaceful setting.

Layer 1 (Background): The garden is surrounded by soft greenery, with vibrant flowers in full bloom, but dark storm clouds begin to gather overhead, casting an ominous shadow. The sky dims, with patches of light breaking through the clouds in the distance.

Layer 2 (Middle ground): The garden's colorful flowers and lush plants sway as strong gusts sweep through, scattering leaves and petals. A light drizzle starts to fall, dampening the vibrant hues of the blooms, creating a visually striking contrast between the garden's natural beauty and the encroaching storm.

Layer 3 (Foreground): In the center of the garden stands a young girl with petite features and curly hair that subtly shifts in color with her emotions. Her face is set in frustration, her hands clenched as she struggles with her emotions. Nearby, an elderly woman with a calm, nurturing expression and silver hair tied back observes with gentle eyes. She wears a soft, worn shawl and extends a supportive hand toward the girl. The interplay of their expressions and postures captures the tension and inner conflict, while the surrounding storm elements intensify the atmosphere, illustrating the girl's struggle for control.""",
                    scene_image_prompt_short="In a digital painting style with watercolor elements, a tranquil garden is disrupted as dark clouds gather. A young girl stands at the center, her curly hair shifting in hue with her emotions, and her small frame visibly tense as she faces inner turmoil. Leaves and petals swirl around her as a strong gust whips through, dimming the vibrant flowers under the darkening sky. Nearby, an elderly woman with silver hair tied back and a gentle, nurturing expression extends a supportive hand, creating a contrast between her calm presence and the stormy, introspective atmosphere.",
                ),
                Scene(
                    scene_id="storm_bringer_influence",
                    title="The Storm Bringer's Influence",
                    description=(
                        "Maya encounters Jonah again in the village. He demonstrates his control over the storm, yet his methods are "
                        "rooted in anger rather than peace. Intrigued and frustrated, Maya tries to understand his approach, leading "
                        "to an intense clash."
                    ),
                    setting="The edge of the village near the cliffs, overlooking a restless sea as winds pick up.",
                    key_actions=[
                        "Jonah calls forth a powerful gust, causing waves to crash violently against the cliffs.",
                        "Maya confronts Jonah, asking why he uses his power with such anger, but Jonah rebuffs her with cynicism.",
                        "As tensions rise, the sky darkens, reflecting their clashing emotions, and Maya realizes the danger of uncontrolled anger."
                    ],
                    characters_involved=["maya", "jonah"],
                    location="Village cliffs",
                    time_of_day="Afternoon",
                    lighting="Dark, stormy skies with occasional flashes of lightning.",
                    mood="Intense and confrontational, highlighting the contrast between control and chaos.",
                    background_animation="Strong winds sweep over the cliffs, carrying the salt spray of crashing waves. Clouds churn above, as lightning crackles in the distance. The sky darkens ominously, and trees bend to the force of the wind.",
                    background_image_prompt="A digital painting style with watercolor elements of a rugged cliffside overlooking a restless sea. Waves crash violently against the rocks below, while strong winds sweep across the cliffs, carrying salt spray and scattered leaves. Above, storm clouds churn in the dark sky, and occasional lightning briefly illuminates the scene, casting a stark, dramatic light on two figures standing at the edge. The atmosphere is intense and confrontational, highlighting a clash of emotions and power between them.",
                    scene_image_prompt="""A digital painting style with watercolor elements of a rugged cliffside overlooking a vast, restless sea, where two figures face each other under a dark, turbulent sky.

Layer 1 (Background): The vast, churning sea stretches to the horizon, with large waves crashing against the rugged rocks below. The sky above is filled with dark, swirling clouds, thick and heavy, casting deep shadows over the scene. Occasional flashes of lightning illuminate the landscape, adding a dramatic, ominous light.

Layer 2 (Middle ground): Strong winds sweep across the cliff, carrying salt spray and swirling leaves. The cliff's rocky edge is jagged, with tufts of hardy grass that bend in the gusts. This middle layer reflects the chaotic, stormy atmosphere, with nature itself appearing agitated, mirroring the tension of the figures.

Layer 3 (Foreground): Near the cliff's edge stands a petite young girl with intense, curly hair that subtly shifts in color, reflecting her emotional state. Her expression is a mix of determination and caution as she faces a tall teenage boy across from her. The boy has wild, dark hair and piercing blue eyes, and he stands with a defiant posture, his worn jacket whipping in the wind. His jaw is set, and his gaze is challenging as he raises an arm, summoning a powerful gust that sends waves crashing below. The lightning briefly illuminates their contrasting expressions—the girl's cautious determination and the boy's fiery anger—capturing the clash of control versus chaos as the storm mirrors their inner conflict and emotional turmoil.""",
                    scene_image_prompt_short="A digital painting style with watercolor elements of a rugged cliff overlooking a stormy sea, where a young girl with shifting curls and a focused gaze stands cautiously at the edge, her dress whipped by the wind. Across from her stands a tall boy with wild hair and piercing eyes, his expression defiant as he summons gusts that send waves crashing below. Lightning illuminates their contrasting expressions—the girl's cautious determination and the boy's fiery anger—as the storm mirrors their inner clash of control and chaos.",
                )
            ]
        ),
        Act(
            act_id="mastery_and_great_storm",
            title="Act 3 - Mastery and the Great Storm",
            scenes=[
                Scene(
                    scene_id="calm_before_storm",
                    title="Calm Before the Storm",
                    description=(
                        "As Maya gains confidence and finds peace within herself, the village braces for an unprecedented storm. "
                        "Her grandmother encourages her to channel her newfound calm to protect her home."
                    ),
                    setting="A gathering in the village square, where villagers prepare for the incoming storm, seeking shelter and reassurance.",
                    key_actions=[
                        "Iris gives Maya a protective charm, symbolizing her growth and readiness.",
                        "Maya assures the villagers that she will do everything she can to protect them, drawing strength from their support.",
                        "As the first winds of the storm roll in, Maya centers herself, feeling the calm within as her power builds."
                    ],
                    characters_involved=["maya", "grandmother"],
                    location="Village square",
                    time_of_day="Evening",
                    lighting="Gray skies with a hint of golden light as the sun sets, casting an eerie calm.",
                    mood="Hopeful yet tense, with an underlying sense of community and resolve.",
                    background_animation="The sky hangs dark and still. A gentle breeze rustles clothing. Soft sunlight filters through the clouds, casting a warm, hopeful glow.",
                    background_image_prompt="A digital painting style with watercolor elements of a quiet village square at dusk, where villagers gather under a gray, ominous sky. A gentle breeze rustles clothing and banners as the sun begins to set, casting a faint golden glow through the clouds. The atmosphere is both tense and hopeful, with villagers preparing for the impending storm and finding reassurance in each other. The scene carries a sense of eerie calm, as if the storm is waiting on the horizon.",
                    
                    scene_image_prompt="""A digital painting style with watercolor elements of a quiet village square at dusk, where a tense and expectant calm fills the atmosphere.

Layer 1 (Background): The sky is thick with gray clouds that hang heavily, casting the village square into a muted shadow. The setting sun peeks through the clouds, casting a soft, golden glow that provides an ethereal lighting to the scene.

Layer 2 (Middle ground): The village square is a simple, open space where villagers have begun to gather, some huddling in small groups with concerned expressions, while others stand watching with quiet hope. Banners and clothing on the villagers rustle gently in the breeze, reflecting the calm before the storm and a sense of unity in the face of impending danger.

Layer 3 (Foreground): At the center of the square stands a young girl with petite features and soft curls that rest in gentle waves, reflecting her newfound inner peace. She holds a small protective charm in her hands, her expression resolute. Beside her, an elderly woman with wise eyes and silver hair tied neatly in a bun offers a final, encouraging look. The two figures are surrounded by villagers, some placing their hands on the young girl's shoulders in support. The subtle movements of the banners and clothing add to the atmosphere of anticipation and solidarity, with the final rays of sunlight illuminating their faces as they prepare to face the storm.""",
                    
                    scene_image_prompt_short="A digital painting style with watercolor elements of a quiet village square at dusk, where a young girl with soft, resting curls stands resolute, holding a charm in her hands. Beside her, an elderly woman with a gentle, encouraging expression watches over her. Villagers gather around, their faces reflecting concern and hope, as banners and clothing rustle in the breeze under the golden light breaking through the gray clouds, filling the scene with quiet unity and anticipation."
                ),
                Scene(
                    scene_id="final_storm",
                    title="The Final Storm",
                    description=(
                        "As the storm strikes with full force, Maya faces her ultimate test, balancing between fear and peace. Jonah "
                        "arrives, initially intent on letting the storm rage, but Maya's determination changes his perspective."
                    ),
                    setting="Open fields outside the village, battered by wind and rain as lightning illuminates the dark sky.",
                    key_actions=[
                        "Maya stands firm, focusing her energy to calm the storm's fury despite its overwhelming power.",
                        "Jonah, seeing Maya's resolve, attempts to help, struggling to suppress his own anger.",
                        "Together, they channel their powers to dispel the storm, creating a quiet, radiant calm as dawn breaks."
                    ],
                    characters_involved=["maya", "jonah"],
                    location="Fields outside the village",
                    time_of_day="Early dawn",
                    lighting="Flashes of lightning give way to the first rays of sunlight, symbolizing hope and renewal.",
                    mood="Epic and transformative, with themes of unity, self-mastery, and reconciliation.",
                    background_animation="Rain pours down in torrents. Lightning illuminates the sky in brief, blinding flashes. ",
                    background_image_prompt="A digital painting style with watercolor elements of an open field outside the village, battered by heavy rain and fierce wind. Flashes of lightning illuminate the dark sky as the storm rages at full force, casting brief, intense light across the scene. Shadows dance amid the chaos, and two figures stand firm against the elements. The atmosphere is epic and transformative, capturing the struggle, resilience, and unity needed to bring calm and balance back to nature.",
                    
                    scene_image_prompt="""A digital painting style with watercolor elements of a vast, open field outside the village, where a powerful storm rages around two determined figures.

Layer 1 (Background): The sky above is dark and stormy, filled with churning clouds that occasionally part to reveal flashes of intense lightning. The heavy rain pours down in torrents, creating an atmosphere of chaos as the storm engulfs the landscape.

Layer 2 (Middle ground): The open field is swept by fierce winds, with tall grass bending and whipping in all directions. The rain strikes the ground heavily, splashing up in waves, while lightning briefly illuminates the scene, casting dramatic, shifting shadows across the field.

Layer 3 (Foreground): A young girl with a small, seemingly fragile frame stands firm at the center of the field. Her wild, curly hair is held back, and she holds her arms steady, her eyes closed in deep concentration as she channels her inner calm to confront the storm. Her expression is one of unwavering focus, defying the fierce winds and rain around her. Across from her stands a tall teenage boy with a rugged appearance, his posture tense as he watches her resolve. His dark hair is blown back by the wind, and his face reflects a mix of frustration and awe, beginning to understand her approach to control. Lightning crackles overhead, illuminating both figures in brief, dramatic flashes, capturing their intense focus as they work together. As the storm begins to calm, the dark clouds gradually part, and the first rays of dawn break through, casting a warm, hopeful light over the field, symbolizing unity, resilience, and transformation as they find peace amidst the storm.""",
                    
                    scene_image_prompt_short="A digital painting style with watercolor elements of a vast field, where a young girl stands firm with calm determination, facing a powerful storm. Her hair held back, she stands focused as lightning briefly illuminates her against the fierce winds and rain. Across from her, a tall teenage boy watches, his expression torn between frustration and awe. As they work together, the dark clouds part, and dawn's warm light breaks through, transforming chaos into calm."

                )
            ]
        )
    ],
    story_beats=[
        StoryBeat(name="Power Discovery", description="Maya learns she can influence the weather with her emotions.", scene="The Storm's Beginning"),
        StoryBeat(name="Seeking Control", description="Maya's grandmother teaches her emotional control.", scene="Grandmother's Wisdom")
    ],
    subplots=[
        Subplot(title="Struggle for Control", description="Maya learns emotional stability to control her powers.", related_characters=["Maya, the Weather Weaver", "Grandmother Iris"]),
        Subplot(title="Conflict with Jonah", description="Maya and Jonah clash due to their differing control over emotions.", related_characters=["Maya, the Weather Weaver", "Jonah, the Storm Bringer"])
    ],
    emotional_arc=[
        EmotionalArc(stage="Overwhelm", description="Maya feels overpowered by her abilities."),
        EmotionalArc(stage="Calm", description="Maya learns control and begins to master her powers.")
    ],
    conflict_type="Man vs. Nature and Man vs. Self",
    themes=["Emotional Control and Power", "Nature as Reflection of Self"],
    motifs=["Weather as Emotion", "Self-Control"]
)

few_shot_examples = [
    {
        "story": few_shot_story,
        "freytags_pyramid": {
            "Exposition": "A simple farmer named Aiden lives a quiet life in the countryside, unaware of his royal lineage.",
            "Rising Action": "Aiden discovers a hidden relic from his family's past and learns about his heritage. With the help of allies, he embarks on a journey to overthrow the tyrant who rules his kingdom.",
            "Climax": "Aiden confronts the tyrant in a decisive battle to reclaim his throne.",
            "Falling Action": "With the tyrant defeated, Aiden begins to rebuild his kingdom and restore peace.",
            "Denouement": "Aiden is crowned king, honored by his people, and vows to rule with justice and compassion."
        }
    },
]

# %%
# Function to generate Freytag's Pyramid using LLM and Graphviz

from graphviz import Digraph
from llama_index.core.llms import ChatMessage
import json
import os
from model import Story
from model_text import llm_json, display_messages
from utils import deindent
from IPython.display import display, Image, Markdown

def generate_freytags_pyramid(story: Story) -> dict:
    # Update system message to prompt for Freytag's Pyramid structure
    system_message = deindent("""
        You are a skilled story editor tasked with organizing a plot into Freytag's Pyramid structure.
        Based on the provided story JSON object, generate a plot summary according to Freytag's Pyramid stages:

        - Exposition: Introduce the setting, main characters, and initial situation.
        - Rising Action: Describe key events that build tension and develop the plot.
        - Climax: Identify the turning point where the main conflict reaches its peak.
        - Falling Action: Outline events that lead to the resolution.
        - Denouemen*: Summarize the conclusion and the final state of the protagonist.

        Output a JSON object with these five properties as keys, each containing the corresponding plot summary as a string.
                              
        **ONLY RESPOND WITH A VALID JSON OBJECT**
    """)

    # Construct the message for the LLM with few-shot examples
    messages = [ChatMessage(role="system", content=system_message)]
    
    # Append each example to the message history
    for example in few_shot_examples:
        messages.append(ChatMessage(role="user", content=example["story"].model_dump_json()))
        messages.append(ChatMessage(role="assistant", content=json.dumps(example["freytags_pyramid"])))

    # Add the user's story prompt to generate the plot overview
    messages.append(ChatMessage(role="user", content=story.model_dump_json()))

    display_messages(messages)

    # Request the LLM to generate the plot structure
    response = llm_json.chat(messages, max_new_tokens=500)
    response_json = response.message.content

    try:
        # Parse the response JSON for Freytag's Pyramid elements
        pyramid_structure = json.loads(response_json)
        return pyramid_structure

    except json.JSONDecodeError as e:
        display(Markdown(f"### Error decoding JSON: {e}"))
        display(Markdown(f"```\n{response_json}\n```"))
        raise

# %%
# Generate the pyramid
pyramid = generate_freytags_pyramid(story)
pyramid
# Out:
# {'project_name': 'Nexus Odyssey',
#  'genre': 'Science Fiction, Adventure',
#  'logline': 'A young gamer discovers her life is intertwined with an alternate reality, the Nexus, and must form an unlikely alliance to confront the dark forces manipulating this virtual world.',
#  'story_summary': {'act_1_title': 'Act 1: The Nexus Revelation',
#   'act_1_description': 'Meera, a skilled but reclusive gamer, experiences strange glitches during her VR gaming sessions that reveal an unexpected connection to the Nexus, an alternate reality. As she delves deeper into this phenomenon, Meera uncovers clues suggesting her unique link to the Nexus might be more than just a mere coincidence.',
#   'act_1_scenes': [{'scene_id': 'nexus_awakening',
#     'title': 'The Awakening',
#     'description': "Meera's VR gaming session transitions into the vibrant world of the Nexus, sparking her curiosity and concern about the nature of her reality.",
#     'setting': "Meera's home gaming setup, transitioning to the Nexus",
#     'time_of_day': 'Late evening',
#     'location': 'Dual Reality: Earth & The Nexus',
#     'lighting': "Neon-lit, with a gradual shift from warm home lighting to the Nexus's vibrant glow",
#     'mood': 'Intrigue and wonder, with a hint of unease',
#     'key_actions': ['Meera experiences her first Nexus-induced glitch.',
#      'She begins to question the nature of her reality.']},
#    {'scene_id': 'midnight_origins',
#     'title': "Uncovering Midnight's Past",
#     'description': 'Meera explores her gaming history, seeking any connections to the Nexus. This nostalgic journey reveals early signs of her unique bond with the virtual world.',
#     'setting': "Meera's cluttered bedroom, focusing on her gaming station and old gaming memorabilia",
#     'time_of_day': 'Afternoon',
#     'location': "Earth (Meera's home)",
#     'lighting': 'Soft, natural light with warm tones',
#     'mood': 'Nostalgic and inquisitive',
#     'key_actions': ['Meera discovers her earliest Nexus-related glitches.',
#      'She realizes her unique connection to the Nexus.']}]},
#  'act_2_title': 'Act 2: The Unlikely Alliance',
#  'act_2_description': "As Meera navigates the challenges of the Nexus, she encounters Jax 'Specter' Lee, a brilliant hacker. Despite initial reservations, they form an alliance to overcome the obstacles within this alternate reality. Along the way, they meet Dr. Zhang 'Zee' Wei, who provides crucial insights into the Nexus's fundamental principles and Meera's integral role within it.",
#  'act_2_scenes': [{'scene_id': 'specter_encounter',
#    'title': 'Meeting Specter',
#    'description': 'Meera encounters Jax in a high-stakes hacking challenge within the Nexus, leading to an uneasy but necessary alliance.',
#    'setting': 'A futuristic, neon-drenched cityscape within the Nexus',
#    'time_of_day': 'Night',
#    'location': 'The Nexus',
#    'lighting': 'Vibrant, pulsing neon lights',
#    'mood': 'Cautious and exploratory',
#    'key_actions': ['Meera and Jax engage in a high-stakes hacking challenge.',
#     'They form an uneasy alliance.']},
#   {'scene_id': 'zee_guidance',
#    'title': "Dr. Wei's Wisdom",
#    'description': "Meera meets Dr. Zhang 'Zee' Wei in a serene, futuristic laboratory within the Nexus. Dr. Wei enlightens Meera on the Nexus's principles and her unique connection, deepening her understanding of this virtual world.",
#    'setting': 'A serene, futuristic laboratory within the Nexus',
#    'time_of_day': 'Afternoon',
#    'location': 'The Nexus',
#    'lighting': 'Soft, calming light with a touch of warmth',
#    'mood': 'Soothing and enlightening',
#    'key_actions': ["Dr. Wei explains the Nexus's fundamental principles.",
#     'Meera gains a deeper understanding of her connection.']}]}

# %%
# Generate a Graphviz diagram based on the structure
draft_dir = f"{settings.STORY_DIR}/draft"
freitag_path = create_freytags_pyramid_graphviz(
    story_title=story.title,
    exposition=pyramid.get("Exposition", "Exposition not provided"),
    rising_action=pyramid.get("Rising Action", "Rising Action not provided"),
    climax=pyramid.get("Climax", "Climax not provided"),
    falling_action=pyramid.get("Falling Action", "Falling Action not provided"),
    denouement=pyramid.get("Denouement", "Denouement not provided"),
    story_dir=draft_dir
)

# Display the generated image
display(Markdown(f"## Freytag's Pyramid for {story.title}"))
display(Image(filename=freitag_path))
# Out:
# ## Freytag's Pyramid for Beyond the Pixel Veil
